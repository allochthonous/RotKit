# %% [markdown]
# # EulerRots.py demo

# %%
# %matplotlib inline
import EulerRots as rotkit
# in order to work correctly, you need to have compiled the fortran routines Rotkit_f for your machine
import os
import pandas as pd
import numpy as np

#only needed for the plots
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %% [markdown]
# Tab-delimited files consisting of sets of finite rotations for different plate pairs are built into a rotation model using the rotsets_from_file function, which generates an initial list of FiniteRotationSet objects.
#
# The original rotation file contains a set of absolute plate rotations for Nubia relative to the Indo-Atlantic hotspot reference frame according to the 'fixed hotspot' model of O'Neill et al. (2005). A second rotation model which instead has the 'moving hotspot' rotations from the same paper can be set up by creating a copy of the original, then swapping in the new hotspot rotations from another file. The insert_rots() function detects that the plate pair for the new rotationset is already represented, and by default asks if you want to substitute in the new one or not. Setting ask to 'False' skips the prompt.

# %%
rotmodel=rotkit.EulerRotationModel(rotkit.load_rotsets('./Datafiles/GlobalRots.txt'))

rotmodel2=rotkit.EulerRotationModel(rotmodel.rotationsets)
#remove ask=False or set it to True to get a Y/n prompt before replacement.
rotmodel2.insert_rots(rotkit.load_rotsets('./Datafiles/NUB_MANTmoving_rots.txt'), ask=False)
# Out:
# Duplicate of finite rotation set for 701-1 found: replaced by new set.

# %% [markdown]
# The .summary() command gives the basic details for the sets of finite rotations in the rotation model. Note how the order has changed in rotmodel2 due the removal and replacement of the Nubia/Indo-Atlantic hotspot rotations

# %%
rotmodel.summary()
# Out:
#     MovingPlate                                    MovingPlateName  \
# 0           101                              North American Craton
# 1           201                              South American Craton
# 2           301               Northern European Craton and Eurasia
# 3           501                                      Indian Craton
# 4           503                                             Arabia
# 5           511                               Central Indian Basin
# 6           701                                     African Craton
# 7           709                                      Somalia Plate
# 8           801                                          Australia
# 9           802                     Antarctica and East Antarctica
# 10          804  Marie Byrdland (Ross Terrane) and West Antarctica
# 11          837                         Kermadec Ridge, SW Pacific
# 12          901                                      Pacific Plate
# 13          901                                      Pacific Plate
# 14          909                          Cocos Plate, East Pacific
# 15          911                          Nazca Plate, East Pacific
#
#     FixedPlate                                     FixedPlateName   N  \
# 0          701                                     African Craton  38
# 1          701                                     African Craton  14
# 2          101                              North American Craton  30
# 3          709                                      Somalia Plate  35
# 4          709                                      Somalia Plate  10
# 5          709                                      Somalia Plate  35
# 6            1               Indo-Atlantic Hotspots (Present Day)  12
# 7          701                                     African Craton   8
# 8          802                     Antarctica and East Antarctica  19
# 9          709                                      Somalia Plate  24
# 10         802                     Antarctica and East Antarctica   8
# 11         901                                      Pacific Plate   2
# 12           3                     Pacific Hotspots (Present Day)  36
# 13         804  Marie Byrdland (Ross Terrane) and West Antarctica  58
# 14         901                                      Pacific Plate  10
# 15         901                                      Pacific Plate  15
#
#     Youngest   Oldest
# 0        0.0  154.300
# 1        0.0   83.000
# 2        0.0   79.075
# 3        0.0   64.745
# 4        0.0   83.000
# 5        0.0   64.745
# 6        0.0  120.000
# 7        0.0  250.000
# 8        0.0   83.000
# 9        0.0  120.400
# 10       0.0  250.000
# 11       0.0    1.000
# 12       0.0  144.600
# 13       0.0  250.000
# 14       0.0   28.283
# 15       0.0   83.000

# %%
rotmodel2.summary()
# Out:
#     MovingPlate                                    MovingPlateName  \
# 0           101                              North American Craton
# 1           201                              South American Craton
# 2           301               Northern European Craton and Eurasia
# 3           501                                      Indian Craton
# 4           503                                             Arabia
# 5           511                               Central Indian Basin
# 6           709                                      Somalia Plate
# 7           801                                          Australia
# 8           802                     Antarctica and East Antarctica
# 9           804  Marie Byrdland (Ross Terrane) and West Antarctica
# 10          837                         Kermadec Ridge, SW Pacific
# 11          901                                      Pacific Plate
# 12          901                                      Pacific Plate
# 13          909                          Cocos Plate, East Pacific
# 14          911                          Nazca Plate, East Pacific
# 15          701                                     African Craton
#
#     FixedPlate                                     FixedPlateName   N  \
# 0          701                                     African Craton  38
# 1          701                                     African Craton  14
# 2          101                              North American Craton  30
# 3          709                                      Somalia Plate  35
# 4          709                                      Somalia Plate  10
# 5          709                                      Somalia Plate  35
# 6          701                                     African Craton   8
# 7          802                     Antarctica and East Antarctica  19
# 8          709                                      Somalia Plate  24
# 9          802                     Antarctica and East Antarctica   8
# 10         901                                      Pacific Plate   2
# 11           3                     Pacific Hotspots (Present Day)  36
# 12         804  Marie Byrdland (Ross Terrane) and West Antarctica  58
# 13         901                                      Pacific Plate  10
# 14         901                                      Pacific Plate  15
# 15           1               Indo-Atlantic Hotspots (Present Day)  10
#
#     Youngest   Oldest
# 0        0.0  154.300
# 1        0.0   83.000
# 2        0.0   79.075
# 3        0.0   64.745
# 4        0.0   83.000
# 5        0.0   64.745
# 6        0.0  250.000
# 7        0.0   83.000
# 8        0.0  120.400
# 9        0.0  250.000
# 10       0.0    1.000
# 11       0.0  144.600
# 12       0.0  250.000
# 13       0.0   28.283
# 14       0.0   83.000
# 15       0.0  120.000

# %% [markdown]
# Each EulerRotationModel is a collection of FiniteRotationSets, which are themselves a collection of EulerRotations:

# %%
rotmodel.rotationsets
# Out:
# [<EulerRots.FiniteRotationSet at 0x118264fd0>,
#  <EulerRots.FiniteRotationSet at 0x11856a750>,
#  <EulerRots.FiniteRotationSet at 0x118596cd0>,
#  <EulerRots.FiniteRotationSet at 0x11852fb50>,
#  <EulerRots.FiniteRotationSet at 0x11853ed50>,
#  <EulerRots.FiniteRotationSet at 0x1184d6c10>,
#  <EulerRots.FiniteRotationSet at 0x1184543d0>,
#  <EulerRots.FiniteRotationSet at 0x118462090>,
#  <EulerRots.FiniteRotationSet at 0x11847f490>,
#  <EulerRots.FiniteRotationSet at 0x1185e7d90>,
#  <EulerRots.FiniteRotationSet at 0x1185f6e10>,
#  <EulerRots.FiniteRotationSet at 0x1185f6fd0>,
#  <EulerRots.FiniteRotationSet at 0x11863d290>,
#  <EulerRots.FiniteRotationSet at 0x1186949d0>,
#  <EulerRots.FiniteRotationSet at 0x1186a2a10>,
#  <EulerRots.FiniteRotationSet at 0x11842cdd0>]

# %%
rotmodel.rotationsets[0].summary()
# Out:
#     MovingPlate  FixedPlate  StartAge   EndAge  RotLat  RotLong  RotAng
# 0           101         701         0    0.000  -77.86   207.09   0.000
# 1           101         701         0    0.780  -77.86   207.09   0.182
# 2           101         701         0    1.770  -77.79   208.99   0.408
# 3           101         701         0    2.581  -78.32   211.01   0.601
# 4           101         701         0    3.580  -78.74   237.97   0.782
# 5           101         701         0    4.180  -78.65   224.07   0.964
# 6           101         701         0    5.230  -79.29   224.81   1.176
# 7           101         701         0    5.894  -79.74   227.43   1.343
# 8           101         701         0    6.567  -79.85   228.27   1.504
# 9           101         701         0    7.432  -80.39   225.37   1.724
# 10          101         701         0    8.072  -80.48   232.45   1.858
# 11          101         701         0    9.025  -80.93   225.32   2.172
# 12          101         701         0    9.740  -79.12   259.79   2.268
# 13          101         701         0   10.949  -80.97   232.83   2.664
# 14          101         701         0   12.401  -80.69   238.24   3.059
# 15          101         701         0   13.703  -80.36   237.11   3.415
# 16          101         701         0   14.612  -79.86   241.65   3.716
# 17          101         701         0   16.014  -80.14   222.31   4.210
# 18          101         701         0   17.230  -79.90   217.71   4.630
# 19          101         701         0   18.281  -79.66   215.06   4.916
# 20          101         701         0   19.048  -79.69   217.76   5.135
# 21          101         701         0   20.131  -78.40   198.84   5.591
# 22          101         701         0   25.823   79.34    28.56   7.040
# 23          101         701         0   33.058   75.99     5.98   9.770
# 24          101         701         0   38.426   74.54     0.19  11.920
# 25          101         701         0   46.264   74.23    -5.01  15.110
# 26          101         701         0   52.364   77.34    -1.61  16.960
# 27          101         701         0   55.904   80.64     6.57  17.900
# 28          101         701         0   65.578   82.74     2.93  20.840
# 29          101         701         0   71.587   81.35    -8.32  22.750
# 30          101         701         0   79.075   78.64   -18.16  26.980
# 31          101         701         0   83.000   76.81   -20.59  29.510
# 32          101         701         0  120.400   66.28   -19.82  54.440
# 33          101         701         0  126.700   66.11   -18.95  56.480
# 34          101         701         0  131.900   65.95   -18.50  57.450
# 35          101         701         0  139.600   66.12   -18.38  59.900
# 36          101         701         0  147.700   66.54   -17.98  62.080
# 37          101         701         0  154.300   67.15   -15.98  64.750

# %%
rotmodel.rotationsets[0].rotations
# Out:
# [<EulerRots.EulerRotation at 0x10ee38390>,
#  <EulerRots.EulerRotation at 0x11842ced0>,
#  <EulerRots.EulerRotation at 0x1184420d0>,
#  <EulerRots.EulerRotation at 0x118442290>,
#  <EulerRots.EulerRotation at 0x118442450>,
#  <EulerRots.EulerRotation at 0x118442610>,
#  <EulerRots.EulerRotation at 0x1184427d0>,
#  <EulerRots.EulerRotation at 0x118442990>,
#  <EulerRots.EulerRotation at 0x118442b50>,
#  <EulerRots.EulerRotation at 0x118442d10>,
#  <EulerRots.EulerRotation at 0x118442ed0>,
#  <EulerRots.EulerRotation at 0x1182460d0>,
#  <EulerRots.EulerRotation at 0x11842ce10>,
#  <EulerRots.EulerRotation at 0x118246390>,
#  <EulerRots.EulerRotation at 0x118246550>,
#  <EulerRots.EulerRotation at 0x118246710>,
#  <EulerRots.EulerRotation at 0x1182468d0>,
#  <EulerRots.EulerRotation at 0x118246a90>,
#  <EulerRots.EulerRotation at 0x118246c50>,
#  <EulerRots.EulerRotation at 0x118246e10>,
#  <EulerRots.EulerRotation at 0x118246fd0>,
#  <EulerRots.EulerRotation at 0x1182551d0>,
#  <EulerRots.EulerRotation at 0x118255390>,
#  <EulerRots.EulerRotation at 0x118255550>,
#  <EulerRots.EulerRotation at 0x118255710>,
#  <EulerRots.EulerRotation at 0x1182558d0>,
#  <EulerRots.EulerRotation at 0x118255a90>,
#  <EulerRots.EulerRotation at 0x118255c50>,
#  <EulerRots.EulerRotation at 0x118255e10>,
#  <EulerRots.EulerRotation at 0x118255fd0>,
#  <EulerRots.EulerRotation at 0x1182641d0>,
#  <EulerRots.EulerRotation at 0x118264390>,
#  <EulerRots.EulerRotation at 0x118264550>,
#  <EulerRots.EulerRotation at 0x118264710>,
#  <EulerRots.EulerRotation at 0x1182648d0>,
#  <EulerRots.EulerRotation at 0x118264a90>,
#  <EulerRots.EulerRotation at 0x118264c50>,
#  <EulerRots.EulerRotation at 0x118264e10>]

# %%
rotmodel.rotationsets[0].rotations[4].details()
# Out:
# MovingPlate                         101
# FixedPlate                          701
# Timescale                     Undefined
# StartChron                         None
# EndChron                         2An.3o
# StartAge                              0
# EndAge                             3.58
# RotLat                           -78.74
# RotLong                          237.97
# RotAng                            0.782
# Kappahat                              1
# a                              2.32e-08
# b                               3.7e-09
# c                             -1.16e-09
# d                              4.66e-09
# e                             -1.74e-09
# f                              2.99e-09
# Points                              897
# Segs                                 59
# Plates                                2
# DOF                                 774
# Source         Merkouriev & Demets 2014
# dtype: object

# %%
rotmodel.rotationsets[0].rotations[4].Covariances
# Out:
# Kappahat    1.000000e+00
# a           2.320000e-08
# b           3.700000e-09
# c          -1.160000e-09
# d           4.660000e-09
# e          -1.740000e-09
# f           2.990000e-09
# dtype: float64

# %% [markdown]
# In addition to simple operations (add, interpolate, invert etc.) there are more complex functions which do the hard work of generating useful products. For the present, the most useful for you are probably get_rots and synthetic_APWP:

# %%
ages=np.arange(10,121,10).tolist()
result=rotmodel.get_rots(101,1,ages)
result.summary()
# Out:
#     MovingPlate  FixedPlate  StartAge  EndAge     RotLat     RotLong  \
# 0           101           1       0.0     0.0 -80.099762  165.044444
# 1           101           1       0.0    10.0 -80.099762  165.044444
# 2           101           1       0.0    20.0 -71.649999  145.646042
# 3           101           1       0.0    30.0  45.983549   85.085372
# 4           101           1       0.0    40.0  56.219305   79.181346
# 5           101           1       0.0    50.0  54.710520  122.754691
# 6           101           1       0.0    60.0  52.042506  119.435353
# 7           101           1       0.0    70.0  53.341250  109.194234
# 8           101           1       0.0    80.0  57.158111  102.973139
# 9           101           1       0.0    90.0  62.360178  112.744141
# 10          101           1       0.0   100.0  58.792561   85.643960
# 11          101           1       0.0   110.0  61.861516   94.131515
# 12          101           1       0.0   120.0  64.338338   70.457358
#
#        RotAng
# 0    0.000000
# 1    3.514117
# 2    8.619361
# 3    5.464017
# 4    8.133418
# 5   16.622270
# 6   19.320818
# 7   18.878964
# 8   21.928720
# 9   32.533444
# 10  36.344010
# 11  43.410585
# 12  38.738760

# %%
result.stagerots().rotations[0].summary()
# Out:
# MovingPlate    101.000000
# FixedPlate       1.000000
# StartAge         0.000000
# EndAge          10.000000
# RotLat         -80.099762
# RotLong        165.044444
# RotAng           3.514117
# dtype: float64

# %%
path=rotmodel.synthetic_APWP(101,1,ages,'IA-Fixed APWP','green')
path2=rotmodel2.synthetic_APWP(101,1,ages,'IA-Moving APWP', 'orange')
path3=rotmodel.synthetic_APWP(101,3,ages, 'PAC-APWP','purple')

path.summary()
# Out:
#    Name  PlateCode  FeatureAge  ReconstructionAge        Lat         Lon  \
# 0   VGP        101         0.0               10.0  89.396065  256.775149
# 1   VGP        101         0.0               20.0  87.288768  239.737393
# 2   VGP        101         0.0               30.0  86.204031  173.119928
# 3   VGP        101         0.0               40.0  85.480298  165.799424
# 4   VGP        101         0.0               50.0  80.419681  205.954926
# 5   VGP        101         0.0               60.0  78.151355  201.791137
# 6   VGP        101         0.0               70.0  78.761284  191.597400
# 7   VGP        101         0.0               80.0  78.158957  183.728174
# 8   VGP        101         0.0               90.0  75.067067  188.250913
# 9   VGP        101         0.0              100.0  71.401366  159.962178
# 10  VGP        101         0.0              110.0  69.910821  164.789974
# 11  VGP        101         0.0              120.0  73.484553  142.874982
#
#     MaxError  MinError  MaxBearing
# 0   0.754324  0.418243  -16.137840
# 1   0.853230  0.667135  107.643082
# 2   1.627906  0.905916  -37.130006
# 3   4.899437  2.659326   96.122746
# 4   4.636614  3.102257  -42.548164
# 5   4.247154  2.847922  115.016084
# 6   5.687736  3.449039  110.319880
# 7   6.565019  3.369222  104.320514
# 8   4.818819  3.185840  124.155529
# 9   2.499382  2.102078   21.851389
# 10  4.693876  2.154045  126.213796
# 11  1.118161  0.630987   -9.627293

# %% [markdown]
# Just to show what this looks like, a quick comparison of the synthetic APWPs for the moving and fixed hotspot reference frame:

# %%
plt.figure(figsize=(15,15))
ax = plt.axes(projection=ccrs.NorthPolarStereo(-100))
ax.set_extent([-180, 180, 65, 90], crs=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.OCEAN, zorder=0)
ax.add_feature(cartopy.feature.LAND, zorder=0, edgecolor='black')
ax.gridlines()

path.mapplot(Ellipses=True)
path2.mapplot(Ellipses=True)
path3.mapplot(Ellipses=True)

# %%
Kilauea=rotkit.Point(pd.Series(['Kilauea',901,0.,0.,19.421097,-155.286762],index=['Name','PlateCode','FeatureAge','ReconstructionAge','Lat','Lon']))

ages=np.arange(0,80,10).tolist()
Hawaii_Pac=Kilauea.flowline(ages,3,rotmodel,'Hawaii_Emperor_Pacific','purple', invert=True)
Hawaii_IAfixed=Kilauea.flowline(ages,1,rotmodel,'Hawaii_Emperor_Pacfic','green', invert=True)
Hawaii_IAmoving=Kilauea.flowline(ages,1,rotmodel2,'Hawaii_Emperor_Pacfic','orange', invert=True)

# %%
plt.figure(figsize=(15,10))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
ax.set_extent([160., 220., 10., 45.])
ax.add_feature(cartopy.feature.OCEAN, zorder=0)
ax.add_feature(cartopy.feature.LAND, zorder=0, edgecolor='black')
ax.gridlines()

Hawaii_Pac.mapplot(Ellipses=True)
Hawaii_IAfixed.mapplot(Ellipses=True)
Hawaii_IAmoving.mapplot(Ellipses=True)

# %%
Kent=rotkit.Point(pd.Series(['Kent',101,0.,0.,41.15,-81.36],index=['Name','PlateCode','FeatureAge','ReconstructionAge','Lat','Lon']))
Kent_Pac=Kent.flowline(ages,3,rotmodel,'Kent_Pacfic','purple')
Kent_IAfixed=Kent.flowline(ages,1,rotmodel,'Kent_IA_fixed','green')
Kent_IAmoving=Kent.flowline(ages,1,rotmodel2,'Kent_IA_moving','orange')

plt.figure(figsize=(10,10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-90, -30, 0, 50])
ax.add_feature(cartopy.feature.OCEAN, zorder=0)
ax.add_feature(cartopy.feature.LAND, zorder=0, edgecolor='black')
ax.gridlines()

Kent_Pac.mapplot()
Kent_IAfixed.mapplot()
Kent_IAmoving.mapplot()

# %%
path4=rotmodel.synthetic_APWP(901,1,ages)
path5=rotmodel.synthetic_APWP(901,3,ages)

plt.figure(figsize=(10,10))
ax = plt.axes(projection=ccrs.NorthPolarStereo(-100))
ax.set_extent([-180, 180, 60, 90], crs=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.OCEAN, zorder=0)
ax.add_feature(cartopy.feature.LAND, zorder=0, edgecolor='black')
ax.gridlines()

plt.plot(path4.Lon, path4.Lat, 'o-',
         color='green', linewidth=1,
         transform=ccrs.Geodetic())

plt.plot(path5.Lon, path5.Lat, 'o-',
         color='purple', linewidth=1,
         transform=ccrs.Geodetic())

# %%
rotkit.find_plate_from_number(901)
# Out:
# LetterCode               PAC
# Description    Pacific Plate
# Name: 901, dtype: object
